# %% [markdown]
# # Neural Network
#
# Neural Network is supervised learning method using non-linear function.(ReLu, tanh,...)
#
# In each node, they execute non-linear function to calculate output.

# %%
import numpy as np
import pandas as pd
import mglearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Tunning

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

# %%
X, y = make_moons(n_samples=100, noise=0.25, random_state=3)

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

mlp = MLPClassifier(solver='lbfgs', random_state=0).fit(X_train, y_train)
mglearn.plots.plot_2d_separator(mlp, X_train, fill=True, alpha=.3)
mglearn.discrete_scatter(X_train[:,0], X_train[:, 1], y_train)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
# Out:
# Text(0,0.5,'Feature 1')

# %% [markdown]
# MLP use 100 hidden units as default. Number of hidden units is regarded as hyperparameter, so it is important to select proper number.

# %%
mlp = MLPClassifier(solver='lbfgs', random_state=0, hidden_layer_sizes=[10])
mlp.fit(X_train, y_train)
mglearn.plots.plot_2d_separator(mlp, X_train, fill=True, alpha=.3)
mglearn.discrete_scatter(X_train[:, 0], X_train[:, 1], y_train)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
# Out:
# Text(0,0.5,'Feature 1')

# %% [markdown]
# This graph shows results of mlp model using 10 hidden units. Since number of hidden layer is 1, Decision boundary consists of 10 linear line.

# %% [markdown]
# # Regularization

# %% [markdown]
# Like using L2 penalty in ridge and other linear classifier, MLP can use it. And There are other methods for regularization.

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 8))
for axx, n_hidden_nodes in zip(axes, [10, 100]):
    for ax, alpha in zip(axx, [0.0001, 0.01, 0.1, 1]):
        mlp = MLPClassifier(solver='lbfgs', random_state=0, hidden_layer_sizes=[n_hidden_nodes, n_hidden_nodes], alpha=alpha)
        mlp.fit(X_train, y_train)
        mglearn.plots.plot_2d_separator(mlp, X_train, fill=True, alpha=.3, ax=ax)
        mglearn.discrete_scatter(X_train[:, 0], X_train[:, 1], y_train, ax=ax)
        ax.set_title("n_hidden=[{}, {}]\nalpha={:.4f}".format(n_hidden_nodes, n_hidden_nodes, alpha))

# %% [markdown]
# It is breif preview of **Neural Network**.I have been learning this sector using MOOC.
#
# Usually, for Neural Network, Using Keras or tensorflow is much more preferable since those library provide many useful functions.
