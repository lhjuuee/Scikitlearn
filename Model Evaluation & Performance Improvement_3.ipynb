# %% [markdown]
# # Model Evaluation & Performance Improvement_3
#
# ## 2. Grid Search
#
# ### 2.4 Asymmetry Grid Search
#
# If you don't want to calculate all of combination, then conditional grid search can be used. It's not that different with
#
# previous one, but there is another list in dictionory.

# %%
# Data load
import numpy as np, pandas as pd
from sklearn.svm import SVC
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=0)

# %%
param_grid = [{'kernel': ['rbf'], 
               'C': [0.001, 0.01, 0.1, 1, 10, 100],
               'gamma': [0.001, 0.01, 0.1, 1, 10, 100]},
              {'kernel': ['linear'],
               'C': [0.001, 0.01, 0.1, 1, 10, 100]}]
print("Grid list:\n{}".format(param_grid))
# Out:
# Grid list:
# [{'kernel': ['rbf'], 'C': [0.001, 0.01, 0.1, 1, 10, 100], 'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}, {'kernel': ['linear'], 'C': [0.001, 0.01, 0.1, 1, 10, 100]}]

# %%
grid_search = GridSearchCV(SVC(), param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Optimized parameters: {}".format(grid_search.best_params_))
print("Best score: {:.2f}".format(grid_search.best_score_))
# Out:
# Optimized parameters: {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# Best score: 0.97

# %%
results = pd.DataFrame(grid_search.cv_results_)
display(results.T)
# Out:
# C:\Anaconda_\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Anaconda_\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Anaconda_\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Anaconda_\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Anaconda_\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Anaconda_\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Anaconda_\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#                                                                0   \
# mean_fit_time                                          0.00238976
# mean_score_time                                       0.000599766
# mean_test_score                                          0.366071
# mean_train_score                                         0.366079
# param_C                                                     0.001
# param_gamma                                                 0.001
# param_kernel                                                  rbf
# params              {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# rank_test_score                                                27
# split0_test_score                                           0.375
# split0_train_score                                       0.363636
# split1_test_score                                        0.347826
# split1_train_score                                       0.370787
# split2_test_score                                        0.363636
# split2_train_score                                       0.366667
# split3_test_score                                        0.363636
# split3_train_score                                       0.366667
# split4_test_score                                        0.380952
# split4_train_score                                       0.362637
# std_fit_time                                          0.000796526
# std_score_time                                        0.000489713
# std_test_score                                          0.0113708
# std_train_score                                        0.00285176
#
#                                                               1   \
# mean_fit_time                                         0.00159507
# mean_score_time                                      0.000598335
# mean_test_score                                         0.366071
# mean_train_score                                        0.366079
# param_C                                                    0.001
# param_gamma                                                 0.01
# param_kernel                                                 rbf
# params              {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# rank_test_score                                               27
# split0_test_score                                          0.375
# split0_train_score                                      0.363636
# split1_test_score                                       0.347826
# split1_train_score                                      0.370787
# split2_test_score                                       0.363636
# split2_train_score                                      0.366667
# split3_test_score                                       0.363636
# split3_train_score                                      0.366667
# split4_test_score                                       0.380952
# split4_train_score                                      0.362637
# std_fit_time                                         0.000488754
# std_score_time                                       0.000488539
# std_test_score                                         0.0113708
# std_train_score                                       0.00285176
#
#                                                              2   \
# mean_fit_time                                        0.00159383
# mean_score_time                                     0.000398588
# mean_test_score                                        0.366071
# mean_train_score                                       0.366079
# param_C                                                   0.001
# param_gamma                                                 0.1
# param_kernel                                                rbf
# params              {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# rank_test_score                                              27
# split0_test_score                                         0.375
# split0_train_score                                     0.363636
# split1_test_score                                      0.347826
# split1_train_score                                     0.370787
# split2_test_score                                      0.363636
# split2_train_score                                     0.366667
# split3_test_score                                      0.363636
# split3_train_score                                     0.366667
# split4_test_score                                      0.380952
# split4_train_score                                     0.362637
# std_fit_time                                        0.000797991
# std_score_time                                      0.000488169
# std_test_score                                        0.0113708
# std_train_score                                      0.00285176
#
#                                                            3   \
# mean_fit_time                                      0.00119715
# mean_score_time                                   0.000598335
# mean_test_score                                      0.366071
# mean_train_score                                     0.366079
# param_C                                                 0.001
# param_gamma                                                 1
# param_kernel                                              rbf
# params              {'C': 0.001, 'gamma': 1, 'kernel': 'rbf'}
# rank_test_score                                            27
# split0_test_score                                       0.375
# split0_train_score                                   0.363636
# split1_test_score                                    0.347826
# split1_train_score                                   0.370787
# split2_test_score                                    0.363636
# split2_train_score                                   0.366667
# split3_test_score                                    0.363636
# split3_train_score                                   0.366667
# split4_test_score                                    0.380952
# split4_train_score                                   0.362637
# std_fit_time                                      0.000398851
# std_score_time                                    0.000488539
# std_test_score                                      0.0113708
# std_train_score                                    0.00285176
#
#                                                             4   \
# mean_fit_time                                       0.00139594
# mean_score_time                                    0.000409126
# mean_test_score                                       0.366071
# mean_train_score                                      0.366079
# param_C                                                  0.001
# param_gamma                                                 10
# param_kernel                                               rbf
# params              {'C': 0.001, 'gamma': 10, 'kernel': 'rbf'}
# rank_test_score                                             27
# split0_test_score                                        0.375
# split0_train_score                                    0.363636
# split1_test_score                                     0.347826
# split1_train_score                                    0.370787
# split2_test_score                                     0.363636
# split2_train_score                                    0.366667
# split3_test_score                                     0.363636
# split3_train_score                                    0.366667
# split4_test_score                                     0.380952
# split4_train_score                                    0.362637
# std_fit_time                                       0.000488617
# std_score_time                                     0.000501345
# std_test_score                                       0.0113708
# std_train_score                                     0.00285176
#
#                                                              5   \
# mean_fit_time                                        0.00179486
# mean_score_time                                      0.00059824
# mean_test_score                                        0.366071
# mean_train_score                                       0.366079
# param_C                                                   0.001
# param_gamma                                                 100
# param_kernel                                                rbf
# params              {'C': 0.001, 'gamma': 100, 'kernel': 'rbf'}
# rank_test_score                                              27
# split0_test_score                                         0.375
# split0_train_score                                     0.363636
# split1_test_score                                      0.347826
# split1_train_score                                     0.370787
# split2_test_score                                      0.363636
# split2_train_score                                     0.366667
# split3_test_score                                      0.363636
# split3_train_score                                     0.366667
# split4_test_score                                      0.380952
# split4_train_score                                     0.362637
# std_fit_time                                         0.00039878
# std_score_time                                      0.000488461
# std_test_score                                        0.0113708
# std_train_score                                      0.00285176
#
#                                                               6   \
# mean_fit_time                                         0.00139594
# mean_score_time                                      0.000199556
# mean_test_score                                         0.366071
# mean_train_score                                        0.366079
# param_C                                                     0.01
# param_gamma                                                0.001
# param_kernel                                                 rbf
# params              {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# rank_test_score                                               27
# split0_test_score                                          0.375
# split0_train_score                                      0.363636
# split1_test_score                                       0.347826
# split1_train_score                                      0.370787
# split2_test_score                                       0.363636
# split2_train_score                                      0.366667
# split3_test_score                                       0.363636
# split3_train_score                                      0.366667
# split4_test_score                                       0.380952
# split4_train_score                                      0.362637
# std_fit_time                                         0.000488714
# std_score_time                                       0.000399113
# std_test_score                                         0.0113708
# std_train_score                                       0.00285176
#
#                                                              7   \
# mean_fit_time                                        0.00139737
# mean_score_time                                     0.000799799
# mean_test_score                                        0.366071
# mean_train_score                                       0.366079
# param_C                                                    0.01
# param_gamma                                                0.01
# param_kernel                                                rbf
# params              {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# rank_test_score                                              27
# split0_test_score                                         0.375
# split0_train_score                                     0.363636
# split1_test_score                                      0.347826
# split1_train_score                                     0.370787
# split2_test_score                                      0.363636
# split2_train_score                                     0.366667
# split3_test_score                                      0.363636
# split3_train_score                                     0.366667
# split4_test_score                                      0.380952
# split4_train_score                                     0.362637
# std_fit_time                                         0.00049037
# std_score_time                                      0.000399953
# std_test_score                                        0.0113708
# std_train_score                                      0.00285176
#
#                                                             8   \
# mean_fit_time                                       0.00119729
# mean_score_time                                    0.000399017
# mean_test_score                                       0.366071
# mean_train_score                                      0.366079
# param_C                                                   0.01
# param_gamma                                                0.1
# param_kernel                                               rbf
# params              {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# rank_test_score                                             27
# split0_test_score                                        0.375
# split0_train_score                                    0.363636
# split1_test_score                                     0.347826
# split1_train_score                                    0.370787
# split2_test_score                                     0.363636
# split2_train_score                                    0.366667
# split3_test_score                                     0.363636
# split3_train_score                                    0.366667
# split4_test_score                                     0.380952
# split4_train_score                                    0.362637
# std_fit_time                                       0.000399018
# std_score_time                                     0.000488694
# std_test_score                                       0.0113708
# std_train_score                                     0.00285176
#
#                                                           9   \
# mean_fit_time                                     0.00139642
# mean_score_time                                  0.000398922
# mean_test_score                                     0.366071
# mean_train_score                                    0.366079
# param_C                                                 0.01
# param_gamma                                                1
# param_kernel                                             rbf
# params              {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}
# rank_test_score                                           27
# split0_test_score                                      0.375
# split0_train_score                                  0.363636
# split1_test_score                                   0.347826
# split1_train_score                                  0.370787
# split2_test_score                                   0.363636
# split2_train_score                                  0.366667
# split3_test_score                                   0.363636
# split3_train_score                                  0.366667
# split4_test_score                                   0.380952
# split4_train_score                                  0.362637
# std_fit_time                                     0.000488617
# std_score_time                                   0.000488578
# std_test_score                                     0.0113708
# std_train_score                                   0.00285176
#
#                                  ...                \
# mean_fit_time                    ...
# mean_score_time                  ...
# mean_test_score                  ...
# mean_train_score                 ...
# param_C                          ...
# param_gamma                      ...
# param_kernel                     ...
# params                           ...
# rank_test_score                  ...
# split0_test_score                ...
# split0_train_score               ...
# split1_test_score                ...
# split1_train_score               ...
# split2_test_score                ...
# split2_train_score               ...
# split3_test_score                ...
# split3_train_score               ...
# split4_test_score                ...
# split4_train_score               ...
# std_fit_time                     ...
# std_score_time                   ...
# std_test_score                   ...
# std_train_score                  ...
#
#                                                            32  \
# mean_fit_time                                      0.00099659
# mean_score_time                                             0
# mean_test_score                                      0.955357
# mean_train_score                                     0.988788
# param_C                                                   100
# param_gamma                                               0.1
# param_kernel                                              rbf
# params              {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# rank_test_score                                             9
# split0_test_score                                    0.958333
# split0_train_score                                   0.988636
# split1_test_score                                           1
# split1_train_score                                   0.977528
# split2_test_score                                           1
# split2_train_score                                   0.977778
# split3_test_score                                    0.863636
# split3_train_score                                          1
# split4_test_score                                    0.952381
# split4_train_score                                          1
# std_fit_time                                      1.50789e-07
# std_score_time                                              0
# std_test_score                                      0.0495662
# std_train_score                                    0.00999451
#
#                                                          33  \
# mean_fit_time                                    0.00099721
# mean_score_time                                 0.000399065
# mean_test_score                                    0.946429
# mean_train_score                                          1
# param_C                                                 100
# param_gamma                                               1
# param_kernel                                            rbf
# params              {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# rank_test_score                                          11
# split0_test_score                                  0.916667
# split0_train_score                                        1
# split1_test_score                                         1
# split1_train_score                                        1
# split2_test_score                                         1
# split2_train_score                                        1
# split3_test_score                                  0.863636
# split3_train_score                                        1
# split4_test_score                                  0.952381
# split4_train_score                                        1
# std_fit_time                                    4.15697e-07
# std_score_time                                  0.000488753
# std_test_score                                    0.0519227
# std_train_score                                           0
#
#                                                           34  \
# mean_fit_time                                      0.0011992
# mean_score_time                                  0.000396442
# mean_test_score                                     0.919643
# mean_train_score                                           1
# param_C                                                  100
# param_gamma                                               10
# param_kernel                                             rbf
# params              {'C': 100, 'gamma': 10, 'kernel': 'rbf'}
# rank_test_score                                           17
# split0_test_score                                      0.875
# split0_train_score                                         1
# split1_test_score                                   0.956522
# split1_train_score                                         1
# split2_test_score                                          1
# split2_train_score                                         1
# split3_test_score                                   0.818182
# split3_train_score                                         1
# split4_test_score                                   0.952381
# split4_train_score                                         1
# std_fit_time                                     0.000397851
# std_score_time                                   0.000485554
# std_test_score                                     0.0647906
# std_train_score                                            0
#
#                                                            35  \
# mean_fit_time                                      0.00139604
# mean_score_time                                   0.000399017
# mean_test_score                                        0.5625
# mean_train_score                                            1
# param_C                                                   100
# param_gamma                                               100
# param_kernel                                              rbf
# params              {'C': 100, 'gamma': 100, 'kernel': 'rbf'}
# rank_test_score                                            24
# split0_test_score                                    0.541667
# split0_train_score                                          1
# split1_test_score                                    0.478261
# split1_train_score                                          1
# split2_test_score                                    0.590909
# split2_train_score                                          1
# split3_test_score                                    0.590909
# split3_train_score                                          1
# split4_test_score                                    0.619048
# split4_train_score                                          1
# std_fit_time                                      0.000488442
# std_score_time                                    0.000488694
# std_test_score                                      0.0496678
# std_train_score                                             0
#
#                                                   36  \
# mean_fit_time                            0.000797892
# mean_score_time                          0.000200558
# mean_test_score                             0.366071
# mean_train_score                            0.366079
# param_C                                        0.001
# param_gamma                                      NaN
# param_kernel                                  linear
# params              {'C': 0.001, 'kernel': 'linear'}
# rank_test_score                                   27
# split0_test_score                              0.375
# split0_train_score                          0.363636
# split1_test_score                           0.347826
# split1_train_score                          0.370787
# split2_test_score                           0.363636
# split2_train_score                          0.366667
# split3_test_score                           0.363636
# split3_train_score                          0.366667
# split4_test_score                           0.380952
# split4_train_score                          0.362637
# std_fit_time                             0.000398946
# std_score_time                           0.000401115
# std_test_score                             0.0113708
# std_train_score                           0.00285176
#
#                                                  37  \
# mean_fit_time                           0.000200129
# mean_score_time                         0.000598717
# mean_test_score                            0.848214
# mean_train_score                           0.855069
# param_C                                        0.01
# param_gamma                                     NaN
# param_kernel                                 linear
# params              {'C': 0.01, 'kernel': 'linear'}
# rank_test_score                                  21
# split0_test_score                          0.916667
# split0_train_score                         0.886364
# split1_test_score                          0.826087
# split1_train_score                          0.88764
# split2_test_score                          0.818182
# split2_train_score                         0.866667
# split3_test_score                          0.772727
# split3_train_score                         0.755556
# split4_test_score                          0.904762
# split4_train_score                         0.879121
# std_fit_time                            0.000400257
# std_score_time                          0.000488851
# std_test_score                            0.0547783
# std_train_score                           0.0503114
#
#                                                 38  \
# mean_fit_time                                    0
# mean_score_time                        0.000998163
# mean_test_score                           0.946429
# mean_train_score                          0.966538
# param_C                                        0.1
# param_gamma                                    NaN
# param_kernel                                linear
# params              {'C': 0.1, 'kernel': 'linear'}
# rank_test_score                                 11
# split0_test_score                         0.958333
# split0_train_score                        0.965909
# split1_test_score                         0.913043
# split1_train_score                        0.977528
# split2_test_score                                1
# split2_train_score                        0.944444
# split3_test_score                         0.909091
# split3_train_score                        0.977778
# split4_test_score                         0.952381
# split4_train_score                        0.967033
# std_fit_time                                     0
# std_score_time                         1.26699e-06
# std_test_score                           0.0332185
# std_train_score                          0.0121316
#
#                                               39  \
# mean_fit_time                        0.000598431
# mean_score_time                      0.000199556
# mean_test_score                         0.973214
# mean_train_score                        0.984368
# param_C                                        1
# param_gamma                                  NaN
# param_kernel                              linear
# params              {'C': 1, 'kernel': 'linear'}
# rank_test_score                                1
# split0_test_score                              1
# split0_train_score                      0.988636
# split1_test_score                       0.956522
# split1_train_score                      0.977528
# split2_test_score                              1
# split2_train_score                      0.977778
# split3_test_score                       0.954545
# split3_train_score                      0.988889
# split4_test_score                       0.952381
# split4_train_score                      0.989011
# std_fit_time                         0.000488617
# std_score_time                       0.000399113
# std_test_score                         0.0223995
# std_train_score                       0.00548507
#
#                                                40  \
# mean_fit_time                           0.0004004
# mean_score_time                       0.000399113
# mean_test_score                          0.964286
# mean_train_score                         0.988813
# param_C                                        10
# param_gamma                                   NaN
# param_kernel                               linear
# params              {'C': 10, 'kernel': 'linear'}
# rank_test_score                                 3
# split0_test_score                        0.958333
# split0_train_score                       0.988636
# split1_test_score                               1
# split1_train_score                       0.988764
# split2_test_score                               1
# split2_train_score                       0.977778
# split3_test_score                        0.909091
# split3_train_score                       0.988889
# split4_test_score                        0.952381
# split4_train_score                              1
# std_fit_time                          0.000490395
# std_score_time                        0.000488811
# std_test_score                          0.0338387
# std_train_score                        0.00702801
#
#                                                 41
# mean_fit_time                          0.000598288
# mean_score_time                                  0
# mean_test_score                           0.964286
# mean_train_score                          0.993258
# param_C                                        100
# param_gamma                                    NaN
# param_kernel                                linear
# params              {'C': 100, 'kernel': 'linear'}
# rank_test_score                                  3
# split0_test_score                         0.958333
# split0_train_score                        0.988636
# split1_test_score                                1
# split1_train_score                        0.988764
# split2_test_score                                1
# split2_train_score                        0.988889
# split3_test_score                         0.909091
# split3_train_score                               1
# split4_test_score                         0.952381
# split4_train_score                               1
# std_fit_time                             0.0004885
# std_score_time                                   0
# std_test_score                           0.0338387
# std_train_score                         0.00550551
#
# [23 rows x 42 columns]

# %% [markdown]
# #### Cross-Validation Options
#
# Like cross_val_score uses cv as a controler of cross-validation option, GridSearchCV is also able to control this.
#
# If you want to split one time, then use n_splits=1 and ShuffleSplit or StratifiedShuffleSplit. It is useful to large dataset.
#
# #### Cross-Validation and Parallelized Grid Search
#
# If there are too many parameters and dataset is large, grid search cause overload on operating, but can be parallelized easily.
#
# In GridSearchCV and cross_val_score, change value of n_jobs to parallelize. If n_jobs=-1, It uses all available core.
#
# But, it can be overlapped. For instance, If you use n_jobs option in algorithm, then you are not able to use n_jobs in GridSearchCV.
